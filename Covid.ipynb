# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
country_list = ['India', 'Korea, South', 'Germany', 'Spain', 'Italy', 'Brazil', 'Thailand', 'Singapore']

# %%
cvd19_confirmed = pd.read_csv('time_series_covid19_confirmed_global.csv')

# %%
cvd19_deaths = pd.read_csv('time_series_covid19_deaths_global.csv')

# %%
cvd19_confirmed.set_index('Country/Region',inplace=True)

# %%
cvd19_confirmed = cvd19_confirmed.drop(['Province/State'], axis=1)
cvd19_confirmed = cvd19_confirmed.drop(['Lat'], axis=1)
cvd19_confirmed = cvd19_confirmed.drop(['Long'], axis=1)

# %%
cvd19_confirmed.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  7/17/20  7/18/20  7/19/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    35229    35301    35475
# Albania               0        0        0  ...     3906     4008     4090
# Algeria               0        0        0  ...    21948    22549    23084
# Andorra               0        0        0  ...      880      880      880
# ...

# %%
confirmed_dataset = pd.DataFrame()

# %%
for country in country_list:
    confirmed_dataset = pd.concat([confirmed_dataset, cvd19_confirmed[cvd19_confirmed.index==country]])

# %%
confirmed_dataset.transpose().head()# = pd.concat([india_confirmed, sk_confirmed, germany_confirmed, spain_confirmed, italy_confirmed])
# Out:
# Country/Region  India  Korea, South  Germany  Spain  Italy  Brazil  Thailand  \
# 1/22/20             0             1        0      0      0       0         2
# 1/23/20             0             1        0      0      0       0         3
# 1/24/20             0             2        0      0      0       0         5
# 1/25/20             0             2        0      0      0       0         7
# 1/26/20             0             3        0      0      0       0         8
#
# Country/Region  Singapore
# 1/22/20                 0
# 1/23/20                 1
# 1/24/20                 3
# 1/25/20                 3
# 1/26/20                 4

# %%
#for x in confirmed_dataset.columns:
#    confirmed_dataset[x] = pd.to_datetime(confirmed_dataset[x])

# %%
confirmed_dataset
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# India                 0        0        0        0        0        0        0
# Korea, South          1        1        2        2        3        4        4
# Germany               0        0        0        0        0        1        4
# Spain                 0        0        0        0        0        0        0
# Italy                 0        0        0        0        0        0        0
# Brazil                0        0        0        0        0        0        0
# Thailand              2        3        5        7        8        8       14
# Singapore             0        1        3        3        4        5        7
#
#                 1/29/20  1/30/20  1/31/20  ...  7/17/20  7/18/20  7/19/20  \
# Country/Region                             ...
# India                 0        1        1  ...  1039084  1077781  1118206
# ...

# %%
confirmed_dataset
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# India                 0        0        0        0        0        0        0
# Korea, South          1        1        2        2        3        4        4
# Germany               0        0        0        0        0        1        4
# Spain                 0        0        0        0        0        0        0
# Italy                 0        0        0        0        0        0        0
# Brazil                0        0        0        0        0        0        0
# Thailand              2        3        5        7        8        8       14
# Singapore             0        1        3        3        4        5        7
#
#                 1/29/20  1/30/20  1/31/20  ...  7/17/20  7/18/20  7/19/20  \
# Country/Region                             ...
# India                 0        1        1  ...  1039084  1077781  1118206
# ...

# %%
transpose_confirmed = confirmed_dataset.transpose()

# %%
transpose_confirmed.reset_index(inplace=True)

# %%
transpose_confirmed.columns = ['Date', 'India', 'South Korea', 'Germany', 'Spain', 'Italy', 'Brazil', 'Thailand', 'Singapore']

# %%
transpose_confirmed['Date'] = pd.to_datetime(transpose_confirmed['Date'], format='%m/%d/%y')

# %%
transpose_confirmed.set_index('Date')
# Out:
#               India  South Korea  Germany   Spain   Italy   Brazil  Thailand  \
# Date
# 2020-01-22        0            1        0       0       0        0         2
# 2020-01-23        0            1        0       0       0        0         3
# 2020-01-24        0            2        0       0       0        0         5
# 2020-01-25        0            2        0       0       0        0         7
# 2020-01-26        0            3        0       0       0        0         8
# ...             ...          ...      ...     ...     ...      ...       ...
# 2020-07-22  1238798        13938   204276  267551  245032  2227514      3261
# 2020-07-23  1288108        13979   204881  270166  245338  2287475      3279
# 2020-07-24  1337024        14092   205623  272421  245590  2343366      3279
# 2020-07-25  1385635        14150   206278  272421  245864  2394513      3282
# 2020-07-26  1435616        14175   206667  272421  246118  2419091      3291
#
#             Singapore
# Date
# ...

# %%
transpose_confirmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         187 non-null    datetime64[ns]
#  1   India        187 non-null    int64
#  2   South Korea  187 non-null    int64
#  3   Germany      187 non-null    int64
#  4   Spain        187 non-null    int64
#  5   Italy        187 non-null    int64
#  6   Brazil       187 non-null    int64
#  7   Thailand     187 non-null    int64
#  8   Singapore    187 non-null    int64
# dtypes: datetime64[ns](1), int64(8)
# memory usage: 13.3 KB

# %%
transpose_confirmed[['India', 'South Korea', 'Germany', 'Italy', 'Spain', 'Brazil', 'Thailand', 'Singapore']].plot(figsize=(20, 10))

# %%
transpose_confirmed[['Date','India']].to_csv('confirmed.csv')
