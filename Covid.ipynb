# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# In C:\Users\souvi\anaconda3\envs\tsa_course\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\souvi\anaconda3\envs\tsa_course\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\souvi\anaconda3\envs\tsa_course\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
country_list = ['India', 'Korea, South', 'Germany', 'Spain', 'Italy', 'Brazil', 'Thailand', 'Singapore']

# %%
cvd19_confirmed = pd.read_csv('time_series_covid19_confirmed_global.csv')

# %%
cvd19_deaths = pd.read_csv('time_series_covid19_deaths_global.csv')

# %%
cvd19_deaths.set_index('Country/Region',inplace=True)

# %%
cvd19_deaths = cvd19_deaths.drop(['Province/State'], axis=1)
cvd19_deaths = cvd19_deaths.drop(['Lat'], axis=1)
cvd19_deaths = cvd19_deaths.drop(['Long'], axis=1)

# %%
cvd19_deaths.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20   ...    5/27/20  5/28/20  5/29/20  \
# Country/Region                              ...
# Afghanistan           0        0        0   ...        227      235      246
# Albania               0        0        0   ...         33       33       33
# Algeria               0        0        0   ...        623      630      638
# Andorra               0        0        0   ...         51       51       51
# ...

# %%
death_dataset = pd.DataFrame()

# %%
for country in country_list:
    death_dataset = pd.concat([death_dataset, cvd19_deaths[cvd19_deaths.index==country]])

# %%
death_dataset.transpose().head()# = pd.concat([india_confirmed, sk_confirmed, germany_confirmed, spain_confirmed, italy_confirmed])
# Out:
# Country/Region  India  Korea, South  Germany  Spain  Italy  Brazil  Thailand  \
# 1/22/20             0             0        0      0      0       0         0
# 1/23/20             0             0        0      0      0       0         0
# 1/24/20             0             0        0      0      0       0         0
# 1/25/20             0             0        0      0      0       0         0
# 1/26/20             0             0        0      0      0       0         0
#
# Country/Region  Singapore
# 1/22/20                 0
# 1/23/20                 0
# 1/24/20                 0
# 1/25/20                 0
# 1/26/20                 0

# %%
#for x in confirmed_dataset.columns:
#    confirmed_dataset[x] = pd.to_datetime(confirmed_dataset[x])

# %%
confirmed_dataset
# Out:
#                         1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                   0        0        0        0        0        0
# Albania                       0        0        0        0        0        0
# Algeria                       0        0        0        0        0        0
# Andorra                       0        0        0        0        0        0
# Angola                        0        0        0        0        0        0
# Antigua and Barbuda           0        0        0        0        0        0
# Argentina                     0        0        0        0        0        0
# Armenia                       0        0        0        0        0        0
# Australia                     0        0        0        0        0        0
# Australia                     0        0        0        0        0        0
# Australia                     0        0        0        0        0        0
# ...

# %%
confirmed_dataset
# Out:
#                         1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                   0        0        0        0        0        0
# Albania                       0        0        0        0        0        0
# Algeria                       0        0        0        0        0        0
# Andorra                       0        0        0        0        0        0
# Angola                        0        0        0        0        0        0
# Antigua and Barbuda           0        0        0        0        0        0
# Argentina                     0        0        0        0        0        0
# Armenia                       0        0        0        0        0        0
# Australia                     0        0        0        0        0        0
# Australia                     0        0        0        0        0        0
# Australia                     0        0        0        0        0        0
# ...

# %%
transpose_death = death_dataset.transpose()

# %%
# transpose_death.reset_index(inplace=True)

# %%
transpose_death.head()
# Out:
# Country/Region  India  Korea, South  Germany  Spain  Italy  Brazil  Thailand  \
# 1/22/20             0             0        0      0      0       0         0
# 1/23/20             0             0        0      0      0       0         0
# 1/24/20             0             0        0      0      0       0         0
# 1/25/20             0             0        0      0      0       0         0
# 1/26/20             0             0        0      0      0       0         0
#
# Country/Region  Singapore
# 1/22/20                 0
# 1/23/20                 0
# 1/24/20                 0
# 1/25/20                 0
# 1/26/20                 0

# %%
transpose_death.columns = ['Date', 'India', 'South Korea', 'Germany', 'Spain', 'Italy', 'Brazil', 'Thailand', 'Singapore']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-ada97a75e53d> in <module>
# ----> 1 transpose_death.columns = ['Date', 'India', 'South Korea', 'Germany', 'Spain', 'Italy', 'Brazil', 'Thailand', 'Singapore']
#
# ~\anaconda3\envs\tsa_course\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\envs\tsa_course\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
# ...

# %%
transpose_death['Date'] = pd.to_datetime(transpose_confirmed['Date'], format='%m/%d/%y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1ceaffd14663> in <module>
# ----> 1 transpose_death['Date'] = pd.to_datetime(transpose_confirmed['Date'], format='%m/%d/%y')
#
# NameError: name 'transpose_confirmed' is not defined

# %%
transpose_death.set_index('Date')

# %%
transpose_death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97 entries, 1/22/20 to 4/27/20
# Data columns (total 8 columns):
# India           97 non-null int64
# Korea, South    97 non-null int64
# Germany         97 non-null int64
# Spain           97 non-null int64
# Italy           97 non-null int64
# Brazil          97 non-null int64
# Thailand        97 non-null int64
# Singapore       97 non-null int64
# dtypes: int64(8)
# memory usage: 9.3+ KB

# %%
transpose_death[['India', 'South Korea', 'Germany', 'Italy', 'Spain', 'Brazil', 'Thailand', 'Singapore']].plot(figsize=(20, 10))

# %%
transpose_death[['Date','India']].to_csv('deaths.csv')

# %%
india_deaths = transpose_death[['India']]

# %%
india_deaths.reset_index(inplace=True)

# %%
india_deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 2 columns):
# index    136 non-null object
# India    136 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
india_deaths.columns = ['Date', 'India']

# %%
india_deaths['Date'] = pd.to_datetime(india_deaths['Date'], format='%m/%d/%y')
# Out:
# C:\Users\souvi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
india_deaths.set_index('Date')
# Out:
#             India
# Date
# 2020-01-22      0
# 2020-01-23      0
# 2020-01-24      0
# 2020-01-25      0
# 2020-01-26      0
# 2020-01-27      0
# 2020-01-28      0
# 2020-01-29      0
# 2020-01-30      0
# 2020-01-31      0
# 2020-02-01      0
# 2020-02-02      0
# 2020-02-03      0
# 2020-02-04      0
# 2020-02-05      0
# 2020-02-06      0
# 2020-02-07      0
# 2020-02-08      0
# 2020-02-09      0
# 2020-02-10      0
# 2020-02-11      0
# 2020-02-12      0
# 2020-02-13      0
# 2020-02-14      0
# 2020-02-15      0
# 2020-02-16      0
# 2020-02-17      0
# 2020-02-18      0
# 2020-02-19      0
# 2020-02-20      0
# ...           ...
# 2020-05-07   1889
# 2020-05-08   1985
# 2020-05-09   2101
# 2020-05-10   2212
# 2020-05-11   2294
# 2020-05-12   2415
# 2020-05-13   2551
# 2020-05-14   2649
# 2020-05-15   2753
# 2020-05-16   2871
# 2020-05-17   3025
# 2020-05-18   3156
# 2020-05-19   3302
# 2020-05-20   3434
# 2020-05-21   3584
# 2020-05-22   3726
# 2020-05-23   3868
# ...

# %%
india_deaths[['Date','India']].to_csv('deaths.csv')
